# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from tools.agent_tools import search_tool, send_email_tool
from middleware.guardrails import build_middleware_stack

# Full layered guardrail stack
production_agent = create_agent(
    model="mistral-small-2506",
    tools=[search_tool, send_email_tool],
    middleware=build_middleware_stack(),
    checkpointer=InMemorySaver(),
)

print("Production-grade agent with modular guardrails created!")
# Out:
# Production-grade agent with modular guardrails created!
